# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
import seaborn as sns

import ipywidgets as widgets
from ipywidgets import interact, interact_manual

from scipy.optimize import fmin_bfgs
from scipy.optimize import fmin

from scipy.io import loadmat #To Read .mat files
import matplotlib.image as mpimg 

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import normalize

from collections import Counter

# %config InlineBackend.figure_format = 'retina'
# %matplotlib inline
matplotlib.rcParams['figure.figsize'] = (12.0,6.0)
print("Setup Complete")
# Out:
# Setup Complete

# %% [markdown]
# # Anomaly Detection

# %%
X = loadmat('data/ex8data1.mat')['X']
Xval = loadmat('data/ex8data1.mat')['Xval']
yval = loadmat('data/ex8data1.mat')['yval']
fig,ax = plt.subplots()
ax.scatter(x=X[:,0],y=X[:,1])

# %%
def getMuSigma(inputData):
    m = inputData.shape[0]
    mu = np.sum(inputData,axis=0)/m
    sigma = np.sum((inputData-mu)**2,axis=0)/m
    return mu,sigma

def estGaussian(inputData,grid):
    mu = getMean(inputData)
    sigma = getSigma(inputData)
    p=1
    if (len(mu)==len(sigma)):
        dim = len(mu)
        for i in range(0,dim):
            m = int(len(grid)/dim)
            print(m)
            X_grid = grid[i*m:(i+1)*m].reshape(50,50)
            p *= 1/sigma[i]/np.sqrt(2*np.pi)*np.exp(-0.5*((X_grid-mu[i])**2)/(sigma[i]**2))*X_grid
    return p 

def multiGauss(mu,sigma,grid):
    sigma = np.diag(sigma)
    m = len(mu)
    grid = grid - mu.T
    p = 1/((2*np.pi)**(m/2)*(np.linalg.det(sigma)**0.5))* np.exp(-0.5* np.sum(X @ np.linalg.pinv(sigma) * X,axis=1))
    return p

# %%
mu,sigma = getMuSigma(X)
xx = np.linspace(0,35,70)
yy = np.linspace(0,35,70)
XX, YY = np.meshgrid(xx,yy)
gridData = np.hstack((XX.flatten()[:,np.newaxis],XX.flatten()[:,np.newaxis]))
print(multiGauss(mu,sigma,gridData)[:,np.newaxis].shape)
ax.contour(XX,YY,multiGauss(mu,sigma,gridData)[:,np.newaxis].reshape(XX.shape))
fig
# Out:
# (307, 1)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-283-22936d39c887> in <module>
#       5 gridData = np.hstack((XX.flatten()[:,np.newaxis],XX.flatten()[:,np.newaxis]))
#       6 print(multiGauss(mu,sigma,gridData)[:,np.newaxis].shape)
# ----> 7 ax.contour(XX,YY,multiGauss(mu,sigma,gridData)[:,np.newaxis].reshape(XX.shape))
#       8 fig
#
# ValueError: cannot reshape array of size 307 into shape (70,70)

# %%
getMuSigma(X)[0].shape
# Out:
# (2,)

# %%
np.hstack((XX.flatten()[:,np.newaxis],YY.flatten()[:,np.newaxis]))
# Out:
# array([[ 0.       ,  0.       ],
#        [ 0.6122449,  0.       ],
#        [ 1.2244898,  0.       ],
#        ...,
#        [28.7755102, 30.       ],
#        [29.3877551, 30.       ],
#        [30.       , 30.       ]])

# %%
# Out:
# array([4332.45331567, 4604.297126  ])

# %%
def estimateGaussian(X):
    """
     This function estimates the parameters of a Gaussian distribution using the data in X
    """
    
    m = X.shape[0]
    
    #compute mean
    sum_ = np.sum(X,axis=0)
    mu = 1/m *sum_
    
    # compute variance
    var = 1/m * np.sum((X - mu)**2,axis=0)
    
    return mu,var
mu, sigma2 = estimateGaussian(X)
